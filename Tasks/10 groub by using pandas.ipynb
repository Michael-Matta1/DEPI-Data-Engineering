# %%
import pandas as pd

data = {
    "title": ["book 1", "book 2", "book 3", "book 4", "book 5", "book 6"],
    "genre": ["adventure", "fantasy", "romance", "adventure", "fantasy", "romance"],
    "qty": [4, 5, 2, 3, 3, 1]
}

df = pd.DataFrame(data)
df
# Out:
#     title      genre  qty
# 0  book 1  adventure    4
# 1  book 2    fantasy    5
# 2  book 3    romance    2
# 3  book 4  adventure    3
# 4  book 5    fantasy    3
# 5  book 6    romance    1

# %%
unique_genres = df['genre'].unique()

results = []

for genre in unique_genres:
    filtered_df = df[df['genre'] == genre]

    total_qty = filtered_df['qty'].sum()

    results.append({"genre": genre, "total": total_qty})
# Out:
# [{'genre': 'adventure', 'total': 7}, {'genre': 'fantasy', 'total': 8}, {'genre': 'romance', 'total': 3}]

# %%
result_df = pd.DataFrame(results)

result_df
# Out:
#        genre  total
# 0  adventure      7
# 1    fantasy      8
# 2    romance      3
